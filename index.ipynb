# %% [markdown]
# Bibliotecas utilizadas

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
import unicodedata
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.metrics import silhouette_score, davies_bouldin_score, calinski_harabasz_score
from sklearn.metrics import adjusted_rand_score
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans
from sklearn.cluster import AgglomerativeClustering
from sklearn.decomposition import PCA

# %%
df_original = pd.read_csv("datatran/datatran_2023_2024_2025.csv")
# Out:
# C:\Users\igor.IGOR-DESKTOP\AppData\Local\Temp\ipykernel_25516\1913272631.py:1: DtypeWarning: Columns (0: latitude, 1: longitude) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_original = pd.read_csv("datatran/datatran_2023_2024_2025.csv")

# %% [markdown]
# # PRÉ PROCESSAMENTO

# %% [markdown]
# ### Transformação de Dados

# %%
df_original['km'] = df_original['km'].str.replace(',', '.', regex=False) # Trocando formatação decimal para evitar perda de dados
df_original['km'] = pd.to_numeric(df_original['km'], errors='coerce')


df = df_original.copy()

# %% [markdown]
# ### Redução de Dimensionalidade

# %%
capitais_brasil = [
    "rio branco",
    "maceio",
    "macapa",
    "manaus",
    "salvador",
    "fortaleza",
    "brasilia",
    "vitoria",
    "goiania",
    "são luis",
    "cuiaba",
    "campo grande",
    "belo horizonte",
    "belem",
    "joão pessoa",
    "curitiba",
    "recife",
    "teresina",
    "rio de janeiro",
    "natal",
    "porto alegre",
    "porto velho",
    "boa vista",
    "florianopolis",
    "são paulo",
    "aracaju",
    "palmas"
]

def normalizar(texto):
    texto = str(texto).strip().lower()
    texto = unicodedata.normalize("NFKD", texto)
    texto = "".join(c for c in texto if not unicodedata.combining(c))
    return texto

def municipio_to_capital(municipio):
    municipio = normalizar(municipio)

    if municipio in capitais_brasil:
        return 1
    else:
        return 0

df['capital'] = df['municipio'].apply(municipio_to_capital)

# %%
def classificar_macro_causa(causa):
    if pd.isna(causa):
        return "Outros"
    
    causa = causa.lower()

    if "pedestre" in causa:
        return "Pedestre"

    if any(palavra in causa for palavra in [
        "chuva", "neblina", "fumaça", 
        "acumulo de água", "acumulo de óleo"
    ]):
        return "Ambiente"
    
    if any(palavra in causa for palavra in [
        "falhas mecânicas", "freio", "suspensão",
        "pneu", "faróis"
    ]):
        return "Mecânica"
    
    if any(palavra in causa for palavra in [
        "pista", "curva", "declive", "ondulação",
        "acostamento", "sinalização", "via",
        "obras", "drenagem", "desvio",
        "faixa", "acesso irregular",
        "semáforo com defeito",
        "elemento de contenção",
        "obstrução"
    ]):
        return "Via"
    
    if any(palavra in causa for palavra in [
        "condutor", "velocidade", "ultrapassagem",
        "manobra", "transitar", "conversão",
        "frear", "racha", "álcool",
        "reação", "mal súbito",
        "distância", "desrespeitou"
    ]):
        return "Condutor"
    
    return "Outros"

df["macro_causa"] = df["causa_acidente"].apply(classificar_macro_causa)

# %%
def mapa_clima(condicao):
    if pd.isna(condicao):
        return "Desconhecido"
    condicao = condicao.strip().lower()
    if condicao in ["céu claro", "sol", "vento"]:
        return "Normal"

    elif condicao in ["chuva", "garoa/chuvisco", "granizo", "neve", "nublado", "nevoeiro/neblina"]:
        return "Adversa"
    
    else:
        return "Desconhecido"
    
df["meteorologia"] = df["condicao_metereologica"].apply(mapa_clima)

# %%
def mapa_macro_tipo(tipo):
    if pd.isna(tipo):
        return "Outros"
    
    tipo = tipo.lower()
    
    if any(palavra in tipo for palavra in [
        "colisão frontal",
        "colisão traseira",
        "colisão transversal",
        "colisão lateral mesmo sentido",
        "colisão lateral sentido oposto",
        "engavetamento"
    ]):
        return "Colisão entre veículos"
    
    if any(palavra in tipo for palavra in [
        "colisão com objeto",
        "derramamento de carga"
    ]):
        return "Colisão com objeto"
    
    if any(palavra in tipo for palavra in [
        "saída de leito",
        "capotamento",
        "tombamento"
    ]):
        return "Perda de controle / saída de pista"
    
    if "atropelamento" in tipo:
        return "Atropelamento"
    
    if any(palavra in tipo for palavra in [
        "queda de ocupante",
        "sinistro pessoal"
    ]):
        return "Sinistro individual"
    
    if any(palavra in tipo for palavra in [
        "incêndio",
        "eventos atípicos"
    ]):
        return "Outros"
    
    return "Outros"

df['macro_tipo'] = df['tipo_acidente'].apply(mapa_macro_tipo)

# %%
def mapa_fase_dia(fase):

    fase = fase.strip().lower()
    if fase in ["amanhecer", "pleno dia"]:
        return 1
    elif fase in ["plena noite", "anoitecer"]:
        return 0
    
df['dia'] = df['fase_dia'].apply(mapa_fase_dia)

# %%
def mapa_dia_semana(dia):

    dia = dia.strip().lower()
    if dia in ["segunda-feira", "terça-feira", "quarta-feira", "quinta-feira", "sexta-feira"]:
        return 1
    elif dia in ["sábado", "domingo"]:
        return 0

    
df['dia_util'] = df['dia_semana'].apply(mapa_dia_semana)

# %%
def rodovia_federal(br):
    if br != 0:
        return 1
    else:
        return 0

df['rodovia_federal'] = df['br'].apply(rodovia_federal)

# %%
colunas_remover = [
    'id',
    'data_inversa',
    'horario',
    'classificacao_acidente',
    'condicao_metereologica',
    'sentido_via',
    'tracado_via',
    'uso_solo',
    'pessoas',
    'feridos_leves',
    'feridos_graves',
    'ilesos',
    'ignorados',
    'veiculos',
    'latitude',
    'longitude',
    'regional',
    'delegacia',
    'uop',
    'municipio',
    'uf',
    'br',
    'causa_acidente',
    'tipo_acidente',
    'fase_dia',
    'dia_semana',
    'km'
]

df = df.drop(columns=colunas_remover)

# %% [markdown]
# ### Amostragem Aleatória Simples
#
# Foi necessário realizar uma amostragem para execução de alguns algoritmos de maior complexidade de O

# %%
df_sample = df.sample(20000, random_state=42)
df_sample
# Out:
#        tipo_pista  mortos  feridos  capital macro_causa meteorologia  \
# 51217     Simples       0        1        0    Condutor       Normal
# 41702     Simples       1        0        0    Pedestre       Normal
# 203655      Dupla       0        1        0    Condutor      Adversa
# 196603      Dupla       0        1        0    Pedestre       Normal
# 147195    Simples       0        2        0         Via       Normal
# ...           ...     ...      ...      ...         ...          ...
# 1684        Dupla       0        1        0    Condutor      Adversa
# 67679     Simples       0        5        0      Outros       Normal
# 170271    Simples       0        1        0    Condutor      Adversa
# 143555      Dupla       0        1        0         Via       Normal
# 167750    Simples       0        1        0         Via       Normal
#
#                                 macro_tipo  dia  dia_util  rodovia_federal
# 51217               Colisão entre veículos    1         0                1
# 41702                        Atropelamento    0         0                1
# 203655  Perda de controle / saída de pista    1         0                1
# 196603                       Atropelamento    1         1                1
# 147195              Colisão entre veículos    1         1                1
# ...                                    ...  ...       ...              ...
# 1684                Colisão entre veículos    0         0                1
# 67679               Colisão entre veículos    0         1                1
# 170271              Colisão entre veículos    0         1                1
# 143555              Colisão entre veículos    1         1                1
# 167750                       Atropelamento    1         0                1
#
# [20000 rows x 10 columns]

# %% [markdown]
# ### One-Hot Encoding
#
# Foi necessário realizar transformação de atributos categóricos em numéricos para execução de algoritmos baseados em distância

# %%
categoricas = [
    'macro_causa',
    'macro_tipo',
    'tipo_pista',
    'meteorologia'
]

df_encoded = pd.get_dummies(df_sample, columns=categoricas, drop_first=False)
df_encoded
# Out:
#         mortos  feridos  capital  dia  dia_util  rodovia_federal  \
# 51217        0        1        0    1         0                1
# 41702        1        0        0    0         0                1
# 203655       0        1        0    1         0                1
# 196603       0        1        0    1         1                1
# 147195       0        2        0    1         1                1
# ...        ...      ...      ...  ...       ...              ...
# 1684         0        1        0    0         0                1
# 67679        0        5        0    0         1                1
# 170271       0        1        0    0         1                1
# 143555       0        1        0    1         1                1
# 167750       0        1        0    1         0                1
#
#         macro_causa_Ambiente  macro_causa_Condutor  macro_causa_Mecânica  \
# 51217                  False                  True                 False
# 41702                  False                 False                 False
# 203655                 False                  True                 False
# 196603                 False                 False                 False
# 147195                 False                 False                 False
# ...                      ...                   ...                   ...
# 1684                   False                  True                 False
# 67679                  False                 False                 False
# 170271                 False                  True                 False
# 143555                 False                 False                 False
# 167750                 False                 False                 False
#
#         macro_causa_Outros  ...  macro_tipo_Colisão entre veículos  \
# 51217                False  ...                               True
# 41702                False  ...                              False
# 203655               False  ...                              False
# 196603               False  ...                              False
# 147195               False  ...                               True
# ...                    ...  ...                                ...
# 1684                 False  ...                               True
# 67679                 True  ...                               True
# 170271               False  ...                               True
# 143555               False  ...                               True
# 167750               False  ...                              False
#
#         macro_tipo_Outros  macro_tipo_Perda de controle / saída de pista  \
# 51217               False                                          False
# 41702               False                                          False
# 203655              False                                           True
# 196603              False                                          False
# 147195              False                                          False
# ...                   ...                                            ...
# 1684                False                                          False
# 67679               False                                          False
# 170271              False                                          False
# 143555              False                                          False
# 167750              False                                          False
#
#         macro_tipo_Sinistro individual  tipo_pista_Dupla  tipo_pista_Múltipla  \
# 51217                            False             False                False
# 41702                            False             False                False
# 203655                           False              True                False
# 196603                           False              True                False
# 147195                           False             False                False
# ...                                ...               ...                  ...
# 1684                             False              True                False
# 67679                            False             False                False
# 170271                           False             False                False
# 143555                           False              True                False
# 167750                           False             False                False
#
#         tipo_pista_Simples  meteorologia_Adversa  meteorologia_Desconhecido  \
# 51217                 True                 False                      False
# 41702                 True                 False                      False
# 203655               False                  True                      False
# 196603               False                 False                      False
# 147195                True                 False                      False
# ...                    ...                   ...                        ...
# 1684                 False                  True                      False
# 67679                 True                 False                      False
# 170271                True                  True                      False
# 143555               False                 False                      False
# 167750                True                 False                      False
#
#         meteorologia_Normal
# 51217                  True
# 41702                  True
# 203655                False
# 196603                 True
# 147195                 True
# ...                     ...
# 1684                  False
# 67679                  True
# 170271                False
# 143555                 True
# 167750                 True
#
# [20000 rows x 24 columns]

# %% [markdown]
# ### Normalização
#
# Foi necessário realizar normalização dos atributos para execução de algoritmos baseados em distância

# %%
df_encoded['mortos_log'] = np.log1p(df_encoded['mortos'])
df_encoded['feridos_log'] = np.log1p(df_encoded['feridos'])

# %%
cols_continuas = ['mortos_log', 'feridos_log']

scaler = StandardScaler()
df_encoded[cols_continuas] = scaler.fit_transform(df_encoded[cols_continuas])

df_scaled = df_encoded

print(df_encoded)
# Out:
#         mortos  feridos  capital  dia  dia_util  rodovia_federal  \
# 51217        0        1        0    1         0                1
# 41702        1        0        0    0         0                1
# 203655       0        1        0    1         0                1
# 196603       0        1        0    1         1                1
# 147195       0        2        0    1         1                1
# ...        ...      ...      ...  ...       ...              ...
# 1684         0        1        0    0         0                1
# 67679        0        5        0    0         1                1
# 170271       0        1        0    0         1                1
# 143555       0        1        0    1         1                1
# 167750       0        1        0    1         0                1
#
#         macro_causa_Ambiente  macro_causa_Condutor  macro_causa_Mecânica  \
# 51217                  False                  True                 False
# 41702                  False                 False                 False
# 203655                 False                  True                 False
# 196603                 False                 False                 False
# 147195                 False                 False                 False
# ...                      ...                   ...                   ...
# 1684                   False                  True                 False
# 67679                  False                 False                 False
# 170271                 False                  True                 False
# 143555                 False                 False                 False
# 167750                 False                 False                 False
#
#         macro_causa_Outros  ...  \
# 51217                False  ...
# 41702                False  ...
# 203655               False  ...
# 196603               False  ...
# 147195               False  ...
# ...                    ...  ...
# 1684                 False  ...
# 67679                 True  ...
# 170271               False  ...
# 143555               False  ...
# 167750               False  ...
#
#         macro_tipo_Perda de controle / saída de pista  \
# 51217                                           False
# 41702                                           False
# 203655                                           True
# 196603                                          False
# 147195                                          False
# ...                                               ...
# 1684                                            False
# 67679                                           False
# 170271                                          False
# 143555                                          False
# 167750                                          False
#
#         macro_tipo_Sinistro individual  tipo_pista_Dupla  tipo_pista_Múltipla  \
# 51217                            False             False                False
# 41702                            False             False                False
# 203655                           False              True                False
# 196603                           False              True                False
# 147195                           False             False                False
# ...                                ...               ...                  ...
# 1684                             False              True                False
# 67679                            False             False                False
# 170271                           False             False                False
# 143555                           False              True                False
# 167750                           False             False                False
#
#         tipo_pista_Simples  meteorologia_Adversa  meteorologia_Desconhecido  \
# 51217                 True                 False                      False
# 41702                 True                 False                      False
# 203655               False                  True                      False
# 196603               False                 False                      False
# 147195                True                 False                      False
# ...                    ...                   ...                        ...
# 1684                 False                  True                      False
# 67679                 True                 False                      False
# 170271                True                  True                      False
# 143555               False                 False                      False
# 167750                True                 False                      False
#
#         meteorologia_Normal  mortos_log  feridos_log
# 51217                  True   -0.266755     0.041425
# 41702                  True    3.175706    -1.601172
# 203655                False   -0.266755     0.041425
# 196603                 True   -0.266755     0.041425
# 147195                 True   -0.266755     1.002282
# ...                     ...         ...          ...
# 1684                  False   -0.266755     0.041425
# 67679                  True   -0.266755     2.644879
# 170271                False   -0.266755     0.041425
# 143555                 True   -0.266755     0.041425
# 167750                 True   -0.266755     0.041425
#
# [20000 rows x 26 columns]

# %% [markdown]
# # ANÁLISE EXPLORATÓRIA

# %% [markdown]
# ### Descrição e histogramas
#
# A partir da descrição dos dados, é observável que a maioria dos acidentes reportados não constaram óbitos, mas tiveram ao menos um ferido. Ao mesmo tempo, nota-se a grande discrepância entre essas contagens, assumindo em casos extremos valores como 37 e 84 mortos e feridos, respectivamente.

# %%
print(df[['mortos', 'feridos']].describe())

fig, axes = plt.subplots(1, 2, figsize=(18, 5))

sns.histplot(df['mortos'], bins=15, ax=axes[0], kde=True, color='red')
axes[0].set_title('Distribuição de Mortos')

sns.histplot(df['feridos'], bins=15, ax=axes[1], kde=True, color='orange')
axes[1].set_title('Distribuição de Feridos')

plt.show()
# Out:
#               mortos        feridos
# count  213418.000000  213418.000000
# mean        0.083536       1.154978
# std         0.348519       1.208910
# min         0.000000       0.000000
# 25%         0.000000       1.000000
# 50%         0.000000       1.000000
# 75%         0.000000       1.000000
# max        37.000000      84.000000

# %%
# Histograma para Tipo de Acidente (Horizontal)
df_original['tipo_acidente'].value_counts().plot(kind='barh', color='salmon')

plt.title('Tipos de Acidentes mais comuns')
plt.xlabel('Quantidade')
plt.ylabel('Tipo')
plt.tight_layout() # Ajusta o layout para não cortar o texto
plt.show()

# %%
df_original['dia_semana'].value_counts().plot(kind='barh', color='salmon')

plt.title('Dias da semana mais comuns em acidentes')
plt.xlabel('Quantidade')
plt.ylabel('Dia da Semana')
plt.show()

# %%
df_original['fase_dia'].value_counts().plot(kind='barh', color='salmon')

plt.title('Fases do dia mais comuns em acidentes')
plt.xlabel('Quantidade')
plt.ylabel('Fase do dia')
plt.tight_layout() 
plt.show()

# %%
df_original['tipo_pista'].value_counts().plot(kind='barh', color='salmon')

plt.title('Tipos de pista mais comuns em acidentes')
plt.xlabel('Quantidade')
plt.ylabel('Tipo de pista')
plt.tight_layout() 
plt.show()

# %%
df_original['condicao_metereologica'].value_counts().plot(kind='barh', color='salmon')

plt.title('Condições meteorológicas mais comuns em acidentes')
plt.xlabel('Quantidade')
plt.ylabel('Condição meteorológica')
plt.tight_layout() 
plt.show()

# %% [markdown]
# A maioria dos acidentes reportados aconteceram durante a tarde em dias úteis. No entanto, os acidentes graves estão majoritariamente concentrados nas sextas e finais de semana à noite

# %%
def pegar_top5(dataframe):
    temp = dataframe.groupby(['dia_semana', 'fase_dia']).size().reset_index(name='contagem')
    temp = temp.sort_values(by='contagem', ascending=False).head(5)
    temp['legenda'] = temp['dia_semana'] + "\n(" + temp['fase_dia'] + ")"
    return temp

df_geral = pegar_top5(df_original)
df_feridos = pegar_top5(df_original[df_original['feridos'] >= 1]) 
df_obitos = pegar_top5(df_original[df_original['mortos'] >= 1])   

fig, ax = plt.subplots(1, 3, figsize=(18, 6))

ax[0].bar(df_geral['legenda'], df_geral['contagem'], color='skyblue')
ax[0].set_title('Top 5: Geral', fontweight='bold')

ax[1].bar(df_feridos['legenda'], df_feridos['contagem'], color='orange')
ax[1].set_title('Top 5: Com Feridos (>=1)', fontweight='bold')

ax[2].bar(df_obitos['legenda'], df_obitos['contagem'], color='crimson')
ax[2].set_title('Top 5: Com Óbitos (>=1)', fontweight='bold')

for a in ax:
    a.tick_params(axis='x', rotation=45)
    a.set_ylabel('Quantidade de Acidentes')
    a.grid(axis='y', linestyle='--', alpha=0.6)

plt.tight_layout() 
plt.show()

# %% [markdown]
# ### Boxplot

# %% [markdown]
# Os plots de **mortos** e **feridos** contém grande concentração próximas de zero, indicando que a grande maioria dos registros não causaram óbito ou ferimento. Ambos também apresentam grande quantidade de outliers.
#
# A análise do boxplot de **mortos** demonstra que apesar dos acidentes com vítimas serem exceção, podem atingir uma grande proporção de vítimas quando ocorrem.
#
# No caso de **feridos**, há uma concentração maior de ocorrências de cerca de um a quarenta feridos. Com o caso mais extremo constando 80 feridos.
#
# Já a análise da **quilometragem** demonstra que metade dos registros ocorreu antes dos 200km rodados, e a outra metade depois. A maior parte dos eventos ocorre entre 100 e 400km. Mas apesar de haver uma forte concentração de dados no início das rodovias, a base de dados cobre acidentes ocorridos em maiores extensões, chegando a trechos mais remotos

# %%
plt.figure(figsize=(20, 5))

plt.subplot(1, 3, 1)
sns.boxplot(data=df_original, y='mortos', color='salmon')
plt.title('Boxplot de Mortos')

plt.subplot(1, 3, 2)
sns.boxplot(data=df_original, y='feridos', color='lightblue')
plt.title('Boxplot de Feridos')

plt.subplot(1, 3, 3)
sns.boxplot(data=df_original, y='km', color='green')
plt.title('Boxplot de KM')

plt.show()

# %% [markdown]
# #### Análise de Outliers com base no Bloxpot
#
# De acordo com a regra de IQR, qualquer acidente que contenha mortos e feridos são considerados outliers. No entanto, devido ao nosso interesse em analisar um cluster de acidentes graves, optamos pela não remoção destes.

# %%
# Regra de IQR (Tukey)

Q1 = df['mortos'].quantile(0.25)
Q3 = df['mortos'].quantile(0.75)
IQR = Q3 - Q1 # IQR (Intervalo Interquantil): mede a dispersão dos 50% centráis 

limite_inferior = Q1 - 1.5 * IQR
limite_superior = Q3 + 1.5 * IQR

outliers = df[(df['mortos'] < limite_inferior) | (df['mortos'] > limite_superior)]

print("Outliers são aqueles com número de mortos menor que", limite_inferior, "ou maior que", limite_superior)
# Out:
# Outliers são aqueles com número de mortos menor que 0.0 ou maior que 0.0

# %%
# Regra de IQR (Tukey)

Q1 = df['feridos'].quantile(0.25)
Q3 = df['feridos'].quantile(0.75)
IQR = Q3 - Q1 # IQR (Intervalo Interquantil): mede a dispersão dos 50% centráis 

limite_inferior = Q1 - 1.5 * IQR
limite_superior = Q3 + 1.5 * IQR

outliers = df[(df['feridos'] < limite_inferior) | (df['feridos'] > limite_superior)]

print("Outliers são aqueles com número de feridos menor que", limite_inferior, "ou maior que", limite_superior)
# Out:
# Outliers são aqueles com número de feridos menor que 1.0 ou maior que 1.0

# %% [markdown]
# ### Rankeamento de acidentes graves

# %%
print("Acidentes com maior número de óbitos:")
display(df.nlargest(5, 'mortos'))

print("Acidentes com maior número de feridos:")
display(df.nlargest(5, 'feridos'))
# Out:
# Acidentes com maior número de óbitos:
#        tipo_pista  mortos  feridos  capital macro_causa meteorologia  \
# 86272     Simples      37       13        0      Outros       Normal
# 68690     Simples      23        9        0    Condutor       Normal
# 204845    Simples      16       21        0    Condutor       Normal
# 85803     Simples      14        1        0         Via       Normal
# 151791    Simples      11       42        0    Condutor       Normal
#
#                                 macro_tipo  dia  dia_util  rodovia_federal
# 86272               Colisão entre veículos    0         0                1
# 68690               Colisão entre veículos    0         0                1
# 204845  Perda de controle / saída de pista    0         1                1
# 85803                  Sinistro individual    1         0                1
# 151791              Colisão entre veículos    0         1                1
# Acidentes com maior número de feridos:
#        tipo_pista  mortos  feridos  capital macro_causa meteorologia  \
# 86251     Simples       5       84        0    Condutor       Normal
# 2963      Simples       3       62        0    Condutor      Adversa
# 14996       Dupla       0       61        0    Condutor       Normal
# 140902    Simples       4       57        0    Condutor      Adversa
# 54666       Dupla       2       50        0    Condutor      Adversa
#
#                                 macro_tipo  dia  dia_util  rodovia_federal
# 86251                   Colisão com objeto    0         1                1
# 2963                Colisão entre veículos    0         1                1
# 14996               Colisão entre veículos    0         1                1
# 140902  Perda de controle / saída de pista    0         1                1
# 54666   Perda de controle / saída de pista    0         1                1

# %% [markdown]
# ### Matriz de Correlação
#
# Foi observado que não há ocorrência de variáveis altamente correlacionadas dentre os atributos que escolhemos para prosseguir a análise. Dessa forma, a redução de redundância não se fez necessária.

# %%
# Selecionando apenas as colunas relacionadas a vítimas, quilometragem, dia de semana e fase do dia
colunas_interesse = ['mortos', 'feridos', 'capital', 'rodovia_federal', 'dia', 'dia_util'] + [c for c in df_encoded.columns if 'meteorologia' in c or 'tipo_pista' in c or 'macro_causa' in c or 'macro_tipo' in c]
corr_df = df_encoded[colunas_interesse].corr(method='spearman')

# Variáveis de interesse para correlação 
vars_corr = ['mortos', 'feridos', 'capital'] + [c for c in df_encoded.columns if 'meteorologia' in c or 'tipo_pista' in c]
target_corr = corr_df[vars_corr].sort_index()

plt.figure(figsize=(15, 13))
sns.heatmap(target_corr, annot=True, cmap='RdBu', center=0, fmt=".2f", vmin=-1, vmax=1)
plt.title('Correlação de Spearman (Toda a base de dados)')
plt.show()

# %% [markdown]
# #### Análise Para Acidentes Graves
# Foi feita uma filtragem para entender qual a relação dos atributos com os acidentes que obtiveram ao menos um ferido e/ou um óbito. A matriz indica que não há grande correlação dos atributos com a gravidade do acidente.

# %%
df_com_vitimas = df_encoded[df_encoded['mortos'] + df_encoded['feridos'] > 0].copy()

# Selecionando apenas as colunas relacionadas a vítimas, quilometragem, dia de semana e fase do dia
colunas_interesse = ['mortos', 'feridos'] + [c for c in df_encoded.columns if 'dia_semana' in c or 'fase_dia' in c or 'meteorologia' in c or 'tipo_pista' in c]
corr_com_vitimas = df_com_vitimas[colunas_interesse].corr(method='spearman')

plt.figure(figsize=(10, 8))

# Verificando a correlação de todas as variáveis apenas contra 'mortos' e 'feridos'
target_corr = corr_com_vitimas[['mortos', 'feridos']].sort_values(by='mortos', ascending=False)

# Ordenar o eixo y alfabeticamente
target_corr = target_corr.sort_index()

sns.heatmap(target_corr, annot=True, cmap='RdBu', fmt=".2f", vmin=-1, vmax=1)
plt.title('Correlação de Spearman Para Acidentes Graves')
plt.show()

# %% [markdown]
# ### Análise de Componentes Principais (PCA)

# %%
pca = PCA()
pca.fit(df_scaled)
exp_var_cumulativa = np.cumsum(pca.explained_variance_ratio_)

plt.figure(figsize=(10, 5))
plt.bar(range(1, len(exp_var_cumulativa) + 1), pca.explained_variance_ratio_, alpha=0.5, align='center', label='Variância individual')
plt.step(range(1, len(exp_var_cumulativa) + 1), exp_var_cumulativa, where='mid', label='Variância cumulativa')
plt.ylabel('Taxa de Variância Explicada')
plt.xlabel('Componentes Principais')
plt.title('Análise de Variância Explicada (PCA)')
plt.axhline(y=0.8, color='r', linestyle='--', label='80% de Variância')
plt.legend(loc='best')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Análise dos Objetivos

# %% [markdown]
# Quais trechos de 1km nas rodovias federais têm densidade de acidentes fatais 3x acima
# da média nacional?

# %%
media_nacional = df_original.groupby(['br', 'km'])['mortos'].sum().mean()

mortos_por_trecho = df_original.groupby(['br', 'km'])['mortos'].sum().reset_index()

trechos_criticos = mortos_por_trecho[mortos_por_trecho['mortos'] >= 3 * media_nacional]

print(f"Média nacional de mortos por trecho de 1km: {media_nacional:.4f}")
print(f"Limiar (3x): {3 * media_nacional:.4f}")
print(f"Trechos críticos encontrados: {len(trechos_criticos)}")
print(trechos_criticos.sort_values('mortos', ascending=False))
# Out:
# Média nacional de mortos por trecho de 1km: 0.2631
# Limiar (3x): 0.7894
# Trechos críticos encontrados: 12986
#         br     km  mortos
# 16000  116  286.5      37
# 46553  324  385.9      23
# 63017  423  127.0      16
# 28154  226    0.0      14
# 15554  116  230.0      11
# ...    ...    ...     ...
# 69      10   39.0       1
# 68      10   38.0       1
# 67      10   37.3       1
# 65      10   35.7       1
# 67664  493   90.0       1
#
# [12986 rows x 3 columns]

# %%
trechos_criticos.groupby('br')['mortos'].sum().sort_values(ascending=False).head(10).plot(kind='barh', color='salmon')
plt.title('10 Rodovias com Maior Número de Mortos em Trechos')
# Out:
# Text(0.5, 1.0, '10 Rodovias com Maior Número de Mortos em Trechos')

# %% [markdown]
# Sextas-feiras à noite concentram 30% dos acidentes com embriaguez, enquanto
# domingos à tarde têm mais colisões traseiras em retornos de viagem?

# %%
embriaguez = df_original[df_original['causa_acidente'].str.lower().str.contains('álcool')]

contexto_dia = embriaguez[embriaguez['dia_semana'].str.lower().str.contains("sexta-feira") & embriaguez['fase_dia'].str.lower().isin(["anoitecer", "plena noite"])]

pct_sexta_noite = len(contexto_dia) / len(embriaguez) * 100


print("Total de acidentes envolvendo embriaguez: ", len(embriaguez))
print("Porcentagem de acidentes em sextas à noite: {:.2f}%".format(pct_sexta_noite))
# Out:
# Total de acidentes envolvendo embriaguez:  11771
# Porcentagem de acidentes em sextas à noite: 8.20%

# %% [markdown]
# As sextas-feiras à noite concentram 8.2% dos acidentes envolvendo embriaguez

# %%
colisao_traseira = df_original[df_original['tipo_acidente'].str.lower().str.contains('colisão traseira')]

contexto_dia = colisao_traseira[colisao_traseira['dia_semana'].str.lower().str.contains("domingo") & colisao_traseira['fase_dia'].str.lower().isin(["pleno dia"])]

pct_domingo_dia = len(contexto_dia) / len(colisao_traseira) * 100

print("Total de colisões traseiras: ", len(colisao_traseira))
print("Porcentagem de colisões traseiras em domingos de dia: {:.2f}%".format(pct_domingo_dia))
# Out:
# Total de colisões traseiras:  41227
# Porcentagem de colisões traseiras em domingos de dia: 6.46%

# %% [markdown]
# Os domingos à tarde concentram 6.46% das colisões traseiras

# %% [markdown]
# Horário de pico em rodovias de acesso às capitais: colisões traseiras são 70% dos
# acidentes?

# %%
# Filtrar rodovias de acesso às capitais em horário de pico
pico_capital = df_original[
    (df_original['municipio'].apply(municipio_to_capital) == 1) &
    (df_original['dia_semana'].str.lower().isin([
        'segunda-feira', 'terça-feira', 'quarta-feira',
        'quinta-feira', 'sexta-feira'
    ])) &
    (df_original['fase_dia'].str.lower() == 'pleno dia')
]

# Total de acidentes no contexto
total_pico = len(pico_capital)

# Colisões traseiras no contexto
traseiras_pico = pico_capital[
    pico_capital['tipo_acidente'].str.lower().str.contains('traseira')
]

pct_traseiras = len(traseiras_pico) / total_pico * 100

print(f"Total de acidentes em horário de pico próximo à capitais: {total_pico}")
print(f"Colisões traseiras nesse contexto: {len(traseiras_pico)}")
print(f"Percentual de colisões traseiras: {pct_traseiras:.2f}%")

if pct_traseiras >= 70:
    print(f"\nA hipótese SE CONFIRMOU: colisões traseiras representam {pct_traseiras:.2f}% dos acidentes.")
else:
    print(f"\nA hipótese NÃO SE CONFIRMOU: colisões traseiras representam apenas {pct_traseiras:.2f}%, abaixo dos 70% esperados.")
# Out:
# Total de acidentes em horário de pico próximo à capitais: 8329
# Colisões traseiras nesse contexto: 2736
# Percentual de colisões traseiras: 32.85%
#
# A hipótese NÃO SE CONFIRMOU: colisões traseiras representam apenas 32.85%, abaixo dos 70% esperados.

# %% [markdown]
# # ALGORITMOS

# %% [markdown]
# ## K-means
#
# Após muitas testagens, foi observado que a mudança de dimensionalidade proveniente da exclusão das colunas relacionadas à causa e tipo do acidente melhoraram significativamente o desempenho do método de clusterização. Por isso, a partir daqui trabalharemos com uma versão reduzida do nosso dataset, passando de 26 para 11 colunas.

# %%
df_scaled_menor = df_scaled[[c for c in df_scaled.columns if 'dia_semana' in c or 'fase_dia' in c or 'meteorologia' in c or 'tipo_pista' in c or c in ['mortos_log', 'feridos_log', 'capital', 'dia', 'dia_util']]]

df_scaled_menor.columns
# Out:
# Index(['capital', 'dia', 'dia_util', 'tipo_pista_Dupla', 'tipo_pista_Múltipla',
#        'tipo_pista_Simples', 'meteorologia_Adversa',
#        'meteorologia_Desconhecido', 'meteorologia_Normal', 'mortos_log',
#        'feridos_log'],
#       dtype='str')

# %% [markdown]
# ### Método do Cotovelo
#
# Aplicando o método do cotovelo para determinar o número ideal de clusters para K-means. O gráfico resultante mostra a soma dos erros quadráticos (inércia) para diferentes valores de K, e o "cotovelo" indica o ponto onde a redução da inércia começa a diminuir significativamente, sugerindo o número ideal de clusters.

# %%
inertia = []
k_range = range(1, 11)

for k in k_range:
    kmeans = KMeans(
        n_clusters=k,
        init="k-means++",
        random_state=42,
        n_init=10
    )
    kmeans.fit(df_scaled_menor)
    inertia.append(kmeans.inertia_)

plt.plot(k_range, inertia)
plt.xlabel("Número de clusters (k)")
plt.ylabel("Inércia")
plt.title("Método do Cotovelo")
plt.show()

# %% [markdown]
# ### Silhouette Score

# %%
sil_scores = []

for k in range(2, 11):
    kmeans = KMeans(
        n_clusters=k,
        init="k-means++",
        random_state=42,
        n_init=20
    )
    labels = kmeans.fit_predict(df_scaled_menor)
    sil_scores.append(silhouette_score(df_scaled_menor, labels))

plt.plot(range(2, 11), sil_scores)
plt.xlabel("Número de clusters (k)")
plt.ylabel("Silhouette Score")
plt.title("Silhouette Score por K")
plt.show()

# %% [markdown]
# Levando em consideração os valores dados pelo silhouette score e a taxa de SSE, vamos fazer a testagem considerando as k quantidade de clusters: 2, 4, 5, 8

# %% [markdown]
# ### ARI

# %%
seeds = [0, 1, 2, 42, 100]
ks = [2, 4, 5, 8]

for k in ks:

    labels_por_semente = []
    
    print(f"\nAvaliando estabilidade para k={k}...")
    
    for s in seeds:
        km_teste = KMeans(n_clusters=k, init='k-means++', random_state=s, n_init=10)
        labels_teste = km_teste.fit_predict(df_scaled_menor)
        labels_por_semente.append(labels_teste)

    ari_do_k = []
    for i in range(len(labels_por_semente)):
        for j in range(i + 1, len(labels_por_semente)):
            score = adjusted_rand_score(labels_por_semente[i], labels_por_semente[j])
            ari_do_k.append(score)

    print(f"-> ARI Médio para k={k}: {np.mean(ari_do_k):.4f}")
    if np.mean(ari_do_k) > 0.8:
        print("Consistência ideal entre sementes")
    else:
        print("Os grupos mudam muito conforme a semente")
# Out:
# Avaliando estabilidade para k=2...
# -> ARI Médio para k=2: 1.0000
# Consistência ideal entre sementes
#
# Avaliando estabilidade para k=4...
# -> ARI Médio para k=4: 0.6648
# Os grupos mudam muito conforme a semente
#
# Avaliando estabilidade para k=5...
# -> ARI Médio para k=5: 1.0000
# Consistência ideal entre sementes
#
# Avaliando estabilidade para k=8...
# -> ARI Médio para k=8: 0.8159
# Consistência ideal entre sementes

# %% [markdown]
# Os resultados indicam que a quantidade de clusters mais estáveis são: k=2, k=5 ou k=8

# %% [markdown]
# ### Aplicação do Algoritmo

# %% [markdown]
# #### Para k = 2

# %%
kmeans_k_2 = KMeans(n_clusters=2, init="k-means++", random_state=42)
df_sample["cluster_k_2"] = kmeans_k_2.fit_predict(df_scaled_menor)
df_sample.groupby("cluster_k_2").mean(numeric_only=True)
# Out:
#                mortos   feridos   capital       dia  dia_util  rodovia_federal
# cluster_k_2
# 0            0.014939  1.676343  0.114883  0.628593  0.689202         0.998676
# 1            0.162351  0.586375  0.052525  0.565789  0.670840         0.995331

# %% [markdown]
# Nota-se uma distribuição proporcional entre os clusters

# %%
df_sample["cluster_k_2"].value_counts()
# Out:
# cluster_k_2
# 0    10576
# 1     9424
# Name: count, dtype: int64

# %%
amostra_indices = df_sample.sample(n=5000, random_state=42).index

X_tsne_input = df_scaled_menor.loc[amostra_indices]

tsne = TSNE(n_components=2, perplexity=40, random_state=42, n_jobs=-1)
X_tsne_coords = tsne.fit_transform(X_tsne_input)

df_plot = df_sample.loc[amostra_indices].copy()
df_plot['tsne_1'] = X_tsne_coords[:, 0]
df_plot['tsne_2'] = X_tsne_coords[:, 1]

plt.figure(figsize=(12, 8))
sns.scatterplot(
    x='tsne_1', 
    y='tsne_2', 
    hue='cluster_k_2', 
    data=df_plot,
    palette='viridis',
    alpha=0.7,
    s=60
)

plt.title('t-SNE: Visualização dos Clusters', fontsize=15)
plt.show()

# %%
s_score_k_2 = silhouette_score(df_scaled_menor, df_sample['cluster_k_2'])
db_score_k_2 = davies_bouldin_score(df_scaled_menor, df_sample['cluster_k_2'])
ch_score_k_2 = calinski_harabasz_score(df_scaled_menor, df_sample['cluster_k_2'])

print(f"Silhouette Score: {s_score_k_2:.4f} (Alvo: > 0.25)")
print(f"Davies-Bouldin Index: {db_score_k_2:.4f} (Quanto menor, melhor)")
print(f"Calinski-Harabasz Index: {ch_score_k_2:.4f} (Quanto maior, melhor)")
# Out:
# Silhouette Score: 0.1782 (Alvo: > 0.25)
# Davies-Bouldin Index: 2.1051 (Quanto menor, melhor)
# Calinski-Harabasz Index: 3760.4470 (Quanto maior, melhor)

# %% [markdown]
# #### Para k = 5

# %%
kmeans_k_2 = KMeans(n_clusters=5, init="k-means++", random_state=42)
df_sample["cluster_k_5"] = kmeans_k_2.fit_predict(df_scaled_menor)
df_sample.groupby("cluster_k_5").mean(numeric_only=True)
# Out:
#                mortos   feridos   capital       dia  dia_util  \
# cluster_k_5
# 0            0.000177  1.343495  0.151188  0.662531  0.718540
# 1            0.000000  1.493472  0.037826  0.628264  0.668203
# 2            0.000000  1.445747  0.071181  0.575738  0.694661
# 3            1.191384  0.872175  0.049435  0.473164  0.642655
# 4            0.000000  0.000000  0.083813  0.526871  0.628919
#
#              rodovia_federal  cluster_k_2
# cluster_k_5
# 0                   0.998050     0.000000
# 1                   0.999040     0.691244
# 2                   0.999566     0.305339
# 3                   1.000000     0.911723
# 4                   0.987204     1.000000

# %% [markdown]
# A distibuição foi parcialmente proporcional, sendo o grupo 3 representante do caso mais raro

# %%
df_sample['cluster_k_5'].value_counts()
# Out:
# cluster_k_5
# 0    5642
# 1    5208
# 2    4608
# 4    3126
# 3    1416
# Name: count, dtype: int64

# %%
amostra_indices = df_sample.sample(n=5000, random_state=42).index

X_tsne_input = df_scaled_menor.loc[amostra_indices]

tsne = TSNE(n_components=2, perplexity=40, random_state=42, n_jobs=-1)
X_tsne_coords = tsne.fit_transform(X_tsne_input)

df_plot = df_sample.loc[amostra_indices].copy()
df_plot['tsne_1'] = X_tsne_coords[:, 0]
df_plot['tsne_2'] = X_tsne_coords[:, 1]

plt.figure(figsize=(12, 8))
sns.scatterplot(
    x='tsne_1', 
    y='tsne_2', 
    hue='cluster_k_5', 
    data=df_plot,
    palette='viridis',
    alpha=0.7,
    s=60
)

plt.title('t-SNE: Visualização dos Clusters', fontsize=15)
plt.show()

# %%
s_score_k_5 = silhouette_score(df_scaled_menor, df_sample['cluster_k_5'])
db_score_k_5 = davies_bouldin_score(df_scaled_menor, df_sample['cluster_k_5'])
ch_score_k_5 = calinski_harabasz_score(df_scaled_menor, df_sample['cluster_k_5'])

print(f"Silhouette Score: {s_score_k_5:.4f} (Alvo: > 0.25)")
print(f"Davies-Bouldin Index: {db_score_k_5:.4f} (Quanto menor, melhor)")
print(f"Calinski-Harabasz Index: {ch_score_k_5:.4f} (Quanto maior, melhor)")
# Out:
# Silhouette Score: 0.2943 (Alvo: > 0.25)
# Davies-Bouldin Index: 1.2617 (Quanto menor, melhor)
# Calinski-Harabasz Index: 6816.4559 (Quanto maior, melhor)

# %% [markdown]
# #### Para k = 8

# %%
kmeans_k_2 = KMeans(n_clusters=8, init="k-means++", random_state=42)
df_sample["cluster_k_8"] = kmeans_k_2.fit_predict(df_scaled_menor)
df_sample.groupby("cluster_k_8").mean(numeric_only=True)
# Out:
#                mortos   feridos   capital       dia  dia_util  \
# cluster_k_8
# 0            0.009990  3.109895  0.105614  0.809705  0.642721
# 1            0.000000  1.246258  0.066634  0.000000  0.626268
# 2            0.000000  1.274979  0.050378  0.540302  0.706549
# 3            1.191565  0.728377  0.049321  0.470336  0.645461
# 4            0.000000  1.217995  0.115488  0.000000  0.666965
# 5            0.000000  1.000000  0.143474  1.000000  0.752697
# 6            0.000000  0.000000  0.083813  0.526871  0.628919
# 7            0.000000  1.226326  0.036602  1.000000  0.715245
#
#              rodovia_federal  cluster_k_2  cluster_k_5
# cluster_k_8
# 0                   0.998573     0.000000     0.790676
# 1                   0.999034     0.625785     0.844520
# 2                   0.999580     0.590680     2.000000
# 3                   1.000000     0.922802     3.000000
# 4                   0.998209     0.000000     0.673232
# 5                   0.998652     0.000000     0.490291
# 6                   0.987204     1.000000     4.000000
# 7                   0.998993     0.773674     1.000000

# %% [markdown]
# Também foi observada uma boa distribuição das instâncias entre os clusters

# %%
df_sample['cluster_k_8'].value_counts()
# Out:
# cluster_k_8
# 5    3708
# 6    3126
# 7    2978
# 2    2382
# 4    2234
# 0    2102
# 1    2071
# 3    1399
# Name: count, dtype: int64

# %%
amostra_indices = df_sample.sample(n=5000, random_state=42).index

X_tsne_input = df_scaled_menor.loc[amostra_indices]

tsne = TSNE(n_components=2, perplexity=40, random_state=42, n_jobs=-1)
X_tsne_coords = tsne.fit_transform(X_tsne_input)

df_plot = df_sample.loc[amostra_indices].copy()
df_plot['tsne_1'] = X_tsne_coords[:, 0]
df_plot['tsne_2'] = X_tsne_coords[:, 1]

plt.figure(figsize=(12, 8))
sns.scatterplot(
    x='tsne_1', 
    y='tsne_2', 
    hue='cluster_k_8', 
    data=df_plot,
    palette='viridis',
    alpha=0.7,
    s=60
)

plt.title('t-SNE: Visualização dos Clusters', fontsize=15)
plt.show()

# %%
s_score_k_8 = silhouette_score(df_scaled_menor, df_sample['cluster_k_8'])
db_score_k_8 = davies_bouldin_score(df_scaled_menor, df_sample['cluster_k_8'])
ch_score_k_8 = calinski_harabasz_score(df_scaled_menor, df_sample['cluster_k_8'])

print(f"Silhouette Score: {s_score_k_8:.4f} (Alvo: > 0.25)")
print(f"Davies-Bouldin Index: {db_score_k_8:.4f} (Quanto menor, melhor)")
print(f"Calinski-Harabasz Index: {ch_score_k_8:.4f} (Quanto maior, melhor)")
# Out:
# Silhouette Score: 0.2811 (Alvo: > 0.25)
# Davies-Bouldin Index: 1.3595 (Quanto menor, melhor)
# Calinski-Harabasz Index: 4958.1953 (Quanto maior, melhor)

# %% [markdown]
# ### Interpretação

# %% [markdown]
# A comparação de desempenho entre todos os K testados indica que a divisão em 5 clusters foi a mais bem sucedida. <br>
# * A métrica de Silhouette indica maior coesão interna entre instâncias de mesmo cluster, e melhor separação entre os demais. <br>
# * Ao mesmo tempo, o Dives-Bouldin index apresentou a menor taxa nessa experimentação, indicando menor similaridade média entre os clusters. <br>
# * E por fim, o index de Calinki Harabasz apresentou o maior número, indicando melhor dispersão entre clusters <br>
#
# Apesar disso, a taxa de silhouette próxima a 0.29 ainda indica uma estrutura de clusterização não muito bem definida. Um possível indicador de dificuldade em definir padrões para acidentes de trânsito

# %%
df_scaled_menor['cluster_k_5'] = df_sample['cluster_k_5']

# %%
df_sample.groupby("cluster_k_5")[[c for c in df_sample.columns if c in ['mortos', 'feridos']]].mean()
# Out:
#                mortos   feridos
# cluster_k_5
# 0            0.000177  1.343495
# 1            0.000000  1.493472
# 2            0.000000  1.445747
# 3            1.191384  0.872175
# 4            0.000000  0.000000

# %%
df_scaled_menor.groupby("cluster_k_5").mean()
# Out:
#               capital       dia  dia_util  tipo_pista_Dupla  \
# cluster_k_5
# 0            0.151188  0.662531  0.718540          0.810174
# 1            0.037826  0.628264  0.668203          0.000000
# 2            0.071181  0.575738  0.694661          0.438368
# 3            0.049435  0.473164  0.642655          0.274718
# 4            0.083813  0.526871  0.628919          0.442418
#
#              tipo_pista_Múltipla  tipo_pista_Simples  meteorologia_Adversa  \
# cluster_k_5
# 0                       0.189826            0.000000              0.000000
# 1                       0.000192            0.999808              0.000000
# 2                       0.108507            0.453125              0.997613
# 3                       0.061441            0.663842              0.264831
# 4                       0.083813            0.473768              0.303263
#
#              meteorologia_Desconhecido  meteorologia_Normal  mortos_log  \
# cluster_k_5
# 0                             0.012052             0.987948   -0.266145
# 1                             0.019393             0.980607   -0.266755
# 2                             0.002387             0.000000   -0.266755
# 3                             0.016949             0.718220    3.498536
# 4                             0.014395             0.682342   -0.266755
#
#              feridos_log
# cluster_k_5
# 0               0.334974
# 1               0.441195
# 2               0.401097
# 3              -0.727869
# 4              -1.601172

# %%
df_sample["cluster_k_5"].value_counts()
# Out:
# cluster_k_5
# 0    5642
# 1    5208
# 2    4608
# 4    3126
# 3    1416
# Name: count, dtype: int64

# %% [markdown]
# #### Descrição dos clusters
#
# cluster 0:
#
# - mais representativa de capitais
# - maior ocorrencia de dias úteis
# - maior ocorrencia de pista dupla
# - meteorologia normal
# - poucos feridos e mortos
# - maior grupo
#
# cluster 1:
#
# - menor ocorrência em capitais
# - maioria em pista simples
# - meteorologia normal
# - poucos feridos e zero mortos
# - segundo maior grupo
#
# cluster 2:
#
# - pouca ocorrência em capitais
# - dia/noite equilibrados
# - representação de pistas simples/duplas equilibrados
# - meteorologia adversa (~99%)
# - zero mortos e poucos feridos
#
# cluster 3:
#
# - maior representativo noturno (~53%)
# - dias úteis (~64%)
# - maior ocorrência de simples (~66%)
# - metereologia normal (~70%)
# - cluster com maior número de mortos
# - menor grupo
#
# cluster 4:
#
# - zero mortos e feridos
# - 2º menor grupo
# - equilíbrio entre pistas duplas/simples
# - meteorologia normal (~68%)

# %% [markdown]
# A partir desse comparativo, é possível a interpretação dos perfis:
#
# ###### Cluster 0 - Acidentes urbanos típicos
#     Representam um alto volume, mas com baixa letalidade.
#     Envolvem as capitais, dias úteis e pistas duplas.
#
# ###### Cluster 1 - Rodovias simples em condições normais
#     Quase totalmente representada por pistas simples, fora de capitais, com meteorologia normal.
#     Ferimentos leves, e zero mortos. Condições típicas.
#
# ###### Cluster 2 - Acidentes em condições adversas
#     Maior representativa de meteorologia adversa, envolve alguns feridos, mas zero mortos.
#     Possivelmente a baixa taxa de letalidade se dá às precauções assumidas pelos motoristas em condições climáticas adversas, como redução de velocidade e atenção redobrada.
#
# ###### Cluster 3 - Acidentes fatais
#     Grupo mais crítico e raro, concentra a maior taxa de letalidade.
#     Baixa representatividade em capitais, que podem indicar menor condição de segurança.
#
# ###### Cluster 4 - Acidentes sem vítimas
#     Grupo mais saudável, sem mortos ou feridos.

# %% [markdown]
# ## Hierárquico Max

# %% [markdown]
# ### Método 1 - Severidade

# %%
# Cálculo do melhor valor para componentes de PCA
pca_full = PCA(random_state=42)
pca_full.fit(df_scaled)

variancia_acumulada = np.cumsum(pca_full.explained_variance_ratio_)
n_90 = np.argmax(variancia_acumulada >= 0.90) + 1

print(f"Componentes para 90% de variância: {n_90}")
print(f"Variância explicada com {n_90} componentes: {variancia_acumulada[n_90-1]:.2%}")
# Out:
# Componentes para 90% de variância: 10
# Variância explicada com 10 componentes: 91.32%

# %%
pca_1 = PCA(n_components=10, random_state=42)
X_pca_1 = pca_1.fit_transform(df_scaled)

model_1 = AgglomerativeClustering(n_clusters=5, linkage='complete')
labels_1 = model_1.fit_predict(X_pca_1)

# %%
colunas_perfil = ['mortos', 'feridos', 'capital', 'dia', 'dia_util', 'rodovia_federal']
colunas_categoricas = ['macro_causa', 'macro_tipo', 'meteorologia', 'tipo_pista']

df_result_1 = df_sample.copy() # Utiliza df_sample e não df_scaled pois queremos as colunas_categoricas sem ohe
df_result_1['cluster'] = labels_1

print("Tamanho dos clusters:")
for c in sorted(set(labels_1)):
    print(f"  Cluster {c}: {(labels_1==c).sum()} pontos ({(labels_1==c).mean():.1%})")

print("\nPerfil numérico:")
print(df_result_1.groupby('cluster')[colunas_perfil].mean().round(2).to_string())

print("\nPerfil categórico:")
print(df_result_1.groupby('cluster')[colunas_categoricas].agg(lambda x: x.mode()[0]).to_string())
# Out:
# Tamanho dos clusters:
#   Cluster 0: 54 pontos (0.3%)
#   Cluster 1: 7 pontos (0.0%)
#   Cluster 2: 3 pontos (0.0%)
#   Cluster 3: 1 pontos (0.0%)
#   Cluster 4: 19935 pontos (99.7%)
#
# Perfil numérico:
#          mortos  feridos  capital   dia  dia_util  rodovia_federal
# cluster
# 0          0.28     9.65     0.02  0.57      0.52              1.0
# 1          1.29    29.86     0.00  0.57      0.57              1.0
# 2          2.00    51.67     0.00  0.67      1.00              1.0
# 3         23.00     9.00     0.00  0.00      0.00              1.0
# 4          0.08     1.12     0.09  0.60      0.68              1.0
#
# Perfil categórico:
#         macro_causa              macro_tipo meteorologia tipo_pista
# cluster
# 0          Condutor  Colisão entre veículos       Normal    Simples
# 1          Condutor  Colisão entre veículos      Adversa    Simples
# 2          Condutor  Colisão entre veículos      Adversa    Simples
# 3          Condutor  Colisão entre veículos       Normal    Simples
# 4          Condutor  Colisão entre veículos       Normal    Simples

# %% [markdown]
# ### Método 2 - Contextual

# %%
df_contextual = df_scaled[[c for c in df_scaled.columns if 'dia_semana' in c or 'fase_dia' in c or 'meteorologia' in c or 'tipo_pista' in c or c in ['capital', 'dia', 'dia_util']]]
 
model_2 = AgglomerativeClustering(n_clusters=5, linkage='complete')
labels_2 = model_2.fit_predict(df_contextual)
 
df_result_2 = df_sample.copy() # Utiliza df_sample e não df_teste pois queremos as colunas_categoricas sem ohe
df_result_2['cluster'] = labels_2

# %%
colunas_perfil = ['mortos', 'feridos', 'capital', 'dia', 'dia_util', 'rodovia_federal']
colunas_categoricas = ['macro_causa', 'macro_tipo', 'meteorologia', 'tipo_pista']

print("Tamanho dos clusters:")
for c in sorted(set(labels_2)):
    print(f"  Cluster {c}: {(labels_2==c).sum()} pontos ({(labels_2==c).mean():.1%})")

print("\nPerfil numérico:")
print(df_result_2.groupby('cluster')[colunas_perfil].mean().round(2).to_string())

print("\nPerfil categórico:")
print(df_result_2.groupby('cluster')[colunas_categoricas].agg(lambda x: x.mode()[0]).to_string())
# Out:
# Tamanho dos clusters:
#   Cluster 0: 5326 pontos (26.6%)
#   Cluster 1: 1903 pontos (9.5%)
#   Cluster 2: 5692 pontos (28.5%)
#   Cluster 3: 249 pontos (1.2%)
#   Cluster 4: 6830 pontos (34.2%)
#
# Perfil numérico:
#          mortos  feridos  capital   dia  dia_util  rodovia_federal
# cluster
# 0          0.08     1.21     0.06  0.55      0.67              1.0
# 1          0.05     1.09     0.19  0.61      0.74              1.0
# 2          0.05     1.10     0.13  0.64      0.70              1.0
# 3          0.10     1.02     0.09  0.26      0.67              1.0
# 4          0.12     1.20     0.04  0.61      0.65              1.0
#
# Perfil categórico:
#         macro_causa              macro_tipo  meteorologia tipo_pista
# cluster
# 0          Condutor  Colisão entre veículos       Adversa    Simples
# 1          Condutor  Colisão entre veículos        Normal   Múltipla
# 2          Condutor  Colisão entre veículos        Normal      Dupla
# 3          Condutor  Colisão entre veículos  Desconhecido    Simples
# 4          Condutor  Colisão entre veículos        Normal    Simples

# %% [markdown]
# ### Métricas

# %% [markdown]
# #### Silhouette, Davies-Bouldin e Calinski-Harabasz

# %%
resultados = []

for X, labels, nome in [
    (X_pca_1, labels_1, 'Severidade'),
    (df_contextual, labels_2, 'Contextual')
]:
    silhouette = silhouette_score(X, labels, sample_size=5000, random_state=42)
    davies     = davies_bouldin_score(X, labels)
    calinski   = calinski_harabasz_score(X, labels)

    resultados.append({
        'Abordagem':           nome,
        'Silhouette':          round(silhouette, 4),
        'Davies-Bouldin':      round(davies, 4),
        'Calinski-Harabasz':   round(calinski, 2)
    })

df_metricas = pd.DataFrame(resultados).set_index('Abordagem')
print(df_metricas.to_string())
# Out:
#             Silhouette  Davies-Bouldin  Calinski-Harabasz
# Abordagem
# Severidade      0.6569           0.465             951.52
# Contextual      0.4127           1.250            5906.71

# %% [markdown]
# #### ARI

# %% [markdown]
# ##### Método 1 - Severidade

# %%
seeds = [0, 1, 2, 42, 100]
resultados_labels = []

for s in seeds:
    teste = AgglomerativeClustering(n_clusters=5, linkage='complete')
    labels_teste = teste.fit_predict(X_pca_1)
    resultados_labels.append(labels_teste)
 
# Comparando as execuções
ari_scores = []

for i in range(1, len(resultados_labels)):
    score = adjusted_rand_score(resultados_labels[0], resultados_labels[i])
    ari_scores.append(score)
 
print(f"ARI Médio entre execuções: {np.mean(ari_scores):.4f} (Alvo: > 0.8)")
# Out:
# ARI Médio entre execuções: 1.0000 (Alvo: > 0.8)

# %% [markdown]
# ##### Método 2 - Contextual

# %%
seeds = [0, 1, 2, 42, 100]
resultados_labels = []

for s in seeds:
    teste = AgglomerativeClustering(n_clusters=5, linkage='complete')
    labels_teste = teste.fit_predict(df_contextual)
    resultados_labels.append(labels_teste)
 
# Comparando as execuções
ari_scores = []

for i in range(1, len(resultados_labels)):
    score = adjusted_rand_score(resultados_labels[0], resultados_labels[i])
    ari_scores.append(score)
 
print(f"ARI Médio entre execuções: {np.mean(ari_scores):.4f} (Alvo: > 0.8)")
# Out:
# ARI Médio entre execuções: 1.0000 (Alvo: > 0.8)

# %% [markdown]
# ### Comparação

# %%
tsne = TSNE(n_components=2, random_state=42, perplexity=30, max_iter=1000)
X_2d_1 = tsne.fit_transform(X_pca_1)
X_2d_2 = tsne.fit_transform(df_contextual)

fig, axes = plt.subplots(1, 2, figsize=(18, 7))
palette = plt.cm.tab10(np.linspace(0, 1, 5))

for ax, X_2d, labels, titulo in zip(
    axes,
    [X_2d_1, X_2d_2],
    [labels_1, labels_2],
    ['Severidade (com mortos/feridos)', 'Contextual (via e meteorologia)']
):
    for i, k in enumerate(sorted(set(labels))):
        mask = labels == k
        ax.scatter(X_2d[mask, 0], X_2d[mask, 1],
                   c=[palette[i]], s=15, alpha=0.6, label=f'Cluster {k}')
    ax.set_title(titulo)
    ax.legend(markerscale=2)

plt.suptitle('Hierárquico Max — Comparação de Abordagens', fontsize=13)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Interpretação

# %% [markdown]
# #### Qualidade do Clustering
# Analisando as métricas entre as duas abordagens, pode-se notar uma contradição interessante. A abordagem com severidade obteve *Silhouette* de 0.6569 e *Davies-Bouldin* de 0.4650, enquanto a abordagem contextual obteve *Silhouette* de 0.4127 e *Davies-Bouldin* de 1.2500. Em um primeiro momento, conclui-se que, portanto, a implementação severidade teve um desempenho melhor que a contextual, uma vez que o melhor valor possível para *Silhouette* fica próximo de 1 e de *Davies-Bouldin* fica próximo de 0. No entanto, após analisar a métrica *Calinski-Harabansz*, nota-se uma grande virada: severidade obteve 951.52 e contextual 5906.71, com uma diferença de 4955.19, muda-se o ponto de vista.
#
# Essa aparente contradição ilustra que nenhuma métrica isolada é suficiente para avaliar a qualidade de um agrupamento. O *Silhouette* e o *Davies-Bouldi*n da abordagem severidade são favorecidos pelo desequilíbrio extremo dos clusters (em que 97.2% dos pontos estão concentrados em um mesmo grupo). O *Calinski-Harabasz*, por sua vez, penaliza esse desequilíbrio, revelando que a abordagem contextual, mesmo que com valores um pouco piores na *Silhouette* e *Davies-Bouldin*, ainda possui uma separação estruturalmente mais rica e equilibrada dos clusters.

# %% [markdown]
# #### Padrões Observados
# ##### Severidade
# A análise de severidade, que inclui "mortos" e "feridos", produziu um clustering desequilibrado, em que magnitudes numéricas prevalecem sobre quaisquer outros padrões. O resultado disso é um cluster 0 que concentra 97.2% dos acidentes e demais clusters representando casos extremos isolados.
#
# **Cluster 0 — Acidentes com múltiplos feridos (0.3%)** <br>
# Com média de 0.28 mortos e 9.65 feridos, representa acidentes de alta gravidade em pistas simples. O elevado número de feridos sugere colisões envolvendo múltiplos veículos ou transporte coletivo.
#
# **Cluster 1 — Acidentes com feridos extremos (0.0%)** <br>
# Com apenas 7 registros e média de 1.29 mortos e 29.86 feridos, predominantemente em condições adversas. Provavelmente corresponde a acidentes envolvendo veículos de transporte coletivo, eventos raros demais para constituir um padrão significativo.
#
# **Clusters 2 e 3 — Outliers catastróficos (0.0%)** <br>
# Com apenas 3 e 1 registros respectivamente, não representam padrões reais — são anomalias estatísticas com 2.00 e 23.00 mortos, provavelmente acidentes envolvendo cargas perigosas ou grandes engavetamentos.
#
# **Cluster 4 — Acidentes comuns (99.7%)** <br>
# Com média de 0.08 mortos e 1.12 feridos, representa o padrão majoritário dos acidentes de trânsito — ocorrências de baixa letalidade, em pistas simples, causadas pelo condutor em condições meteorológicas normais. A concentração de quase todos os registros neste grupo confirma que a grande maioria dos acidentes nas rodovias federais brasileiras resulta em danos moderados.
# <br>
#
# ##### Contextual
# A análise contextual, ao considerar apenas variáveis de via e condições climáticas, revelou cinco perfis distintos de acidentes nas rodovias federais brasileiras entre 2023 e 2025:
#
# **Cluster 0 — Condições adversas (26.6%)** <br>
# O único cluster com 100% de meteorologia adversa, com distribuição equilibrada entre pista simples e dupla. Ocorre mais à noite (dia=0.55) e menos em capitais (6%), representando acidentes sob chuva ou neblina onde as condições climáticas são o fator determinante independentemente do tipo de via.
#
# **Cluster 1 — Pista múltipla / dias úteis (9.5%)** <br>
# 100% pista múltipla, com alta concentração em dias úteis (74%) e em capitais (19%). Perfil característico de rodovias expressas e perimetrais urbanas com alto fluxo no horário comercial.
#
# **Cluster 2 — Pista dupla / condições normais (28.5%)** <br>
# 100% pista dupla e 100% meteorologia normal, ocorrendo predominantemente durante o dia (64%) em dias úteis (70%). Representa o perfil mais comum de acidentes em rodovias federais duplicadas em condições favoráveis.
#
# **Cluster 3 — Meteorologia desconhecida / noturno (1.2%)** <br>
# O menor cluster, com 100% de meteorologia desconhecida e predominância noturna (74%). Provavelmente representa registros com falha no preenchimento da condição meteorológica, concentrados em acidentes noturnos em rodovias rurais onde o registro é menos rigoroso.
#
# **Cluster 4 — Pista simples / condições normais (34.2%)** <br>
# O maior cluster, com 100% pista simples e 100% meteorologia normal. Representa o cenário mais comum do interior brasileiro — rodovias simples em boas condições climáticas, onde o volume e a infraestrutura da via são os principais fatores de risco.
